# %% [markdown]
# ### Servicios

# %%
import overpy

api = overpy.Overpass()
lat, lon = 3.37308764457703000000,-76.52465057373050000000
radius_deg = 0.01  # aprox. 1km

query = f"""
    node["amenity"](around:1000,{lat},{lon});
    out;
"""
result = api.query(query)
servicios = [{"name": n.tags.get("name", ""), "amenity": n.tags.get("amenity", ""), "lat": n.lat, "lon": n.lon} for n in result.nodes]

# %%
print(servicios)
# Out:
# [{'name': '', 'amenity': 'doctors', 'lat': Decimal('3.3808650'), 'lon': Decimal('-76.5218799')}, {'name': 'CAI, Centro de Alimentación Inmediata', 'amenity': 'restaurant', 'lat': Decimal('3.3755820'), 'lon': Decimal('-76.5332212')}, {'name': 'Comidas Rápidas', 'amenity': 'fast_food', 'lat': Decimal('3.3750599'), 'lon': Decimal('-76.5331891')}, {'name': 'Bancolombia', 'amenity': 'bank', 'lat': Decimal('3.3669347'), 'lon': Decimal('-76.5296291')}, {'name': '', 'amenity': 'bicycle_parking', 'lat': Decimal('3.3754810'), 'lon': Decimal('-76.5325344')}, {'name': '', 'amenity': 'bicycle_parking', 'lat': Decimal('3.3754803'), 'lon': Decimal('-76.5328238')}, {'name': 'Royal Films', 'amenity': 'cinema', 'lat': Decimal('3.3701004'), 'lon': Decimal('-76.5276306')}, {'name': 'Plazoleta de Comidas', 'amenity': 'restaurant', 'lat': Decimal('3.3701265'), 'lon': Decimal('-76.5271827')}, {'name': 'Algo en común', 'amenity': 'arts_centre', 'lat': Decimal('3.3774305'), 'lon': Decimal('-76.5286975')}, {'
# ...

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import random
import time
from functools import lru_cache

import overpy
from overpy import exception
from tqdm import tqdm

df = pd.read_parquet("../data/processed/housing_clean.parquet")
print(df)
# Out:
#              Precio                                             Título  \
# 0      4.197285e+08  ZOLEA GOLDEN LIVING, Apartaestudios en Venta e...
# 1      2.090000e+08  ANDINO APARTAMENTOS, Apartaestudios en Venta e...
# 2      3.900000e+08                  Apartaestudio en Venta en Armenia
# 3      1.410000e+08       Apartaestudio en Venta en Oro Negro, Armenia
# 4      1.450000e+08                  Apartaestudio en venta en Armenia
# ...             ...                                                ...
# 60498  1.900000e+09                             Lote en  Venta en Chía
# 60499  6.500000e+07        Lote en  Venta en Paso de la bolsa, Jamundí
# 60500  1.300000e+08                      Lote en Venta en Sur, Jamundí
# 60501  3.750000e+08                Lote en venta en La Morada, Jamundí
# 60502  1.998000e+09                Lote en venta en Arroyohondo, Yumbo
#
#                                              URL detalle  \
# ...

# %% [markdown]
# # Functions

# %%
# ------------------------------------------------------------------------
# 1. CONFIGURACIÓN GLOBAL
# ------------------------------------------------------------------------
OVERPASS_ENDPOINTS = [
    "https://overpass-api.de/api/interpreter",
    "https://overpass.openstreetmap.ru/api/interpreter",
    "https://overpass.private.coffee/api/interpreter",
]

MAX_TRIES = 5         # reintentos por consulta
BASE_WAIT = 10        # s de back-off inicial
TIMEOUT_S = 180       # timeout de red deseado (segundos)

# ------------------------------------------------------------------------
# 2. FUNCIÓN ROBUSTA DE CONSULTA
# ------------------------------------------------------------------------
def query_overpass(query: str,
                   max_tries: int = MAX_TRIES,
                   timeout: int = TIMEOUT_S):
    """Hace la consulta con reintentos, back-off y rotación de nodos."""
    for attempt in range(max_tries):
        url = OVERPASS_ENDPOINTS[attempt % len(OVERPASS_ENDPOINTS)]
        api = overpy.Overpass(url=url)                # ¡sin timeout aquí!

        try:
            # Probar primero con timeout por si la versión lo soporta
            try:
                result = api.query(query, timeout=timeout)
            except TypeError:                         # versiones antiguas
                result = api.query(query)

            return result

        except (exception.OverpassGatewayTimeout,
                exception.OverpassTooManyRequests) as err:
            wait = (BASE_WAIT * 2**attempt) + random.uniform(0, 5)
            print(f"{err} – reintento {attempt+1}/{max_tries} "
                  f"en {wait:.1f}s ({url})")
            time.sleep(wait)

    print("⚠️  Se agotaron los reintentos.")
    return None

# ------------------------------------------------------------------------
# 3. FUNCIÓN CON CACHÉ POR PUNTO
# ------------------------------------------------------------------------
@lru_cache(maxsize=512)
def fetch_amenity_counts(lat: float, lon: float, radius: int = 1000) -> dict:
    """Devuelve {amenity: n} para todos los amenities en `radius` m."""
    query = f"""
        [timeout:{TIMEOUT_S}][out:json];
        (
          node["amenity"](around:{radius},{lat},{lon});
          way["amenity"](around:{radius},{lat},{lon});
          rel["amenity"](around:{radius},{lat},{lon});
        );
        out center;
    """

    result = query_overpass(query)
    if result is None:
        return {}

    elements = list(result.nodes) + result.ways + result.relations
    counts = {}
    for el in elements:
        if (amen := el.tags.get("amenity")):
            counts[amen] = counts.get(amen, 0) + 1
    return counts

# %% [markdown]
# # PROCESAR EL DATAFRAME

# %%
# ------------------------------------------------------------------------
# 4. PROCESAR EL DATAFRAME
#     • `df` debe contener 'Latitud' y 'Longitud'
# ------------------------------------------------------------------------
results, amenity_set = [], set()

for _, row in tqdm(df.iterrows(), total=len(df), desc="Consultando Overpass"):
    lat, lon = row["Latitud"], row["Longitud"]
    counts = (
        fetch_amenity_counts(float(lat), float(lon))
        if pd.notna(lat) and pd.notna(lon)
        else {}
    )
    results.append(counts)
    amenity_set.update(counts.keys())
    time.sleep(5)                          # pausa cortés
# Out:
# ...
# Consultando Overpass:  17%|█▋        | 10199/60503 [15:31:51<73:18:51,  5.25s/it]
# Server load too high – reintento 1/5 en 14.2s (https://overpass-api.de/api/interpreter)
# Consultando Overpass:  17%|█▋        | 10199/60503 [15:32:45<76:40:34,  5.49s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 28, in query_overpass(query, max_tries, timeout)
#      27 try:
# ---> 28     result = api.query(query, timeout=timeout)
#      29 except TypeError:                         # versiones antiguas
#
# TypeError: Overpass.query() got an unexpected keyword argument 'timeout'
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# ...

# %%
# ------------------------------------------------------------------------
# 5. CONSTRUIR Y UNIR RESULTADOS
# ------------------------------------------------------------------------
df_counts = pd.DataFrame(results).fillna(0).astype(int)

for amen in sorted(amenity_set):
    if amen not in df_counts.columns:
        df_counts[amen] = 0

df_counts = df_counts.add_prefix("n_")
df_full = pd.concat([df.reset_index(drop=True),
                     df_counts.reset_index(drop=True)], axis=1)

# ------------------------------------------------------------------------
# 6. GUARDAR
# ------------------------------------------------------------------------
output_path = "data/processed/housing_clean_w_services.parquet"
df_full.to_parquet(output_path)
print(f"✅ Terminado. Archivo guardado en: {output_path}")
print("Columnas añadidas (primeras 15):", list(df_counts.columns)[:15], "…")
